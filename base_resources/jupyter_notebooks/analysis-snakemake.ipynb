# %%
import subprocess
result = subprocess.run(
    ["snakemake", "-s", "/opt/snakemake/wrangler_by_sample_setup.smk", "-c", "8", "-f"],
    check=True,
    capture_output=True,
    text=True
)
print(result.stdout)

# %%
import subprocess
result = subprocess.run(
    ["snakemake", "-s", "/opt/snakemake/wrangler_by_sample_finish.smk", "-c", "8", "-f"],
    check=True,
    capture_output=True,
    text=True
)
print(result.stdout)

# %%
import subprocess
result = subprocess.run(
    ["snakemake", "-s", "/opt/snakemake/02_check_run_stats.smk", "-c", "8", "-f", "check_wrangler_output"],
    check=True,
    capture_output=True,
    text=True
)
print(result.stdout)

# %%
import sys
sys.path.append("/opt/src")
import mip_functions as mip
import subprocess
result = subprocess.run(
    ["snakemake", "-s", "/opt/snakemake/02_check_run_stats.smk", "-c", "8", "-f", "modify_ozkan_settings"],
    check=True,
    capture_output=True,
    text=True
)
print(result.stdout)
settings = mip.get_analysis_settings(f"/opt/user/stats_and_variant_calling/settings.txt")
print(settings['mipSetKey'])

# %%
import subprocess
result = subprocess.run(
    ["snakemake", "-s", "/opt/snakemake/02_check_run_stats.smk", "-c", "8", "-f", "parse_info_file"],
    check=True,
    capture_output=True,
    text=True
)
print(result.stdout)

# %%
import subprocess
result = subprocess.run(
    ["snakemake", "-s", "/opt/snakemake/02_check_run_stats.smk", "-c", "8", "-f", "map_haplotypes"],
    check=True,
    capture_output=True,
    text=True
)
print(result.stdout)

# %%
import subprocess
result = subprocess.run(
    ["snakemake", "-s", "/opt/snakemake/02_check_run_stats.smk", "-c", "8", "-f", "graph_UMIs"],
    check=True,
    capture_output=True,
    text=True
)
print(result.stdout)

# %%
import subprocess
result = subprocess.run(
    ["snakemake", "-s", "/opt/snakemake/03_generate_contigs.smk", "-c", "8", "-f", "generate_contigs"],
    check=True,
    capture_output=True,
    text=True
)
print(result.stdout)

# %%
import subprocess
result = subprocess.run(
    ["snakemake", "-s", "/opt/snakemake/04_run_freebayes.smk", "-c", "8", "-f", "concatenate_and_fix_vcf_headers"],
    check=True,
    capture_output=True,
    text=True
)
print(result.stdout)

# %%
import subprocess
result = subprocess.run(
    ["snakemake", "-s", "/opt/snakemake/04_run_freebayes.smk", "-c", "8", "-f", "compress_vcf"],
    check=True,
    capture_output=True,
    text=True
)
print(result.stdout)

# %%
import subprocess
result = subprocess.run(
    ["snakemake", "-s", "/opt/snakemake/04_run_freebayes.smk", "-c", "8", "-f", "generate_tables"],
    check=True,
    capture_output=True,
    text=True
)
print(result.stdout)

# %%
import subprocess
result = subprocess.run(
    ["snakemake", "-s", "/opt/snakemake/05_filter_variants.smk", "-c", "8", "-f", "genotype_calls"],
    check=True,
    capture_output=True,
    text=True
)
print(result.stdout)
