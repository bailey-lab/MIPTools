# %% [markdown]
# ## COI estimation with RealMcCOIL
# This notebook shows an example of how [RealMcCOIL](https://github.com/EPPIcenter/THEREALMcCOIL) (via [McCoilR package](https://github.com/OJWatson/McCOILR)) can be used to estimate complexity of infection from MIP data. Please see the linked repositories for the corresponding packages for more information and options to use for the programs.

# %%
# import modules to use
import sys
sys.path.append("/opt/src")
import numpy as np
import pandas as pd

# %% [markdown]
# We are going to need a genotype table. Use the **processing-and-filtering-variant-calls.ipynb** template to create a genotype table from your variant calls. It is important to create a high confidence genotype set, so you should make sure to use filtering steps described in that notebook.

# %% [markdown]
# Load the genotype table from file. The genotypes called using the standard pipeline will have 0 for homozygous reference, 1 for mixed, 2 for homozygous alternate allele and N/A where genotypes are missing.

# %%
genotype_file = "genotypes.csv"
genotypes = pd.read_csv(genotype_file, header=list(range(6)),
                               index_col=0)
genotypes.head()
# Out:
# CHROM                      chr1                                    \
# POS                      139191          139192            140820
# REF                           C               C                 A
# ALT                           T               T                 C
# Mutation Name chr1:139191:.:C:T chr1:139192:C:T chr1:140820:.:A:C
# Targeted                    Yes              No               Yes
# D10-DRC-17                  1.0             1.0               0.0
# D10-DRC-11                  1.0             0.0               1.0
# D10-JJJ-62                  1.0             1.0               0.0
# D10-JJJ-41                  1.0             1.0               0.0
# D10-JJJ-56                  1.0             1.0               1.0
#
# CHROM                                                              \
# POS                      155939          155977            155978
# REF                           G               G                 C
# ALT                           A               A                 T
# Mutation Name chr1:155939:.:G:A chr1:155977:G:A chr1:155978:.:C:T
# Targeted                    Yes              No               Yes
# D10-DRC-17                  1.0             1.0               1.0
# D10-DRC-11                  1.0             1.0               1.0
# D10-JJJ-62                  1.0             1.0               1.0
# D10-JJJ-41                  1.0             1.0               1.0
# D10-JJJ-56                  1.0             1.0               1.0
#
# CHROM                                                              \
# POS                      308232            308385          349247
# REF                           C                 G               C
# ALT                           T                 C               T
# Mutation Name chr1:308232:.:C:T chr1:308385:.:G:C chr1:349247:C:T
# Targeted                    Yes               Yes              No
# D10-DRC-17                  0.0               0.0             1.0
# D10-DRC-11                  1.0               1.0             1.0
# D10-JJJ-62                  1.0               1.0             1.0
# D10-JJJ-41                  0.0               1.0             1.0
# D10-JJJ-56                  0.0               0.0             1.0
#
# CHROM                            ...              chr9                    \
# POS                      349253  ...            817567            831911
# REF                           A  ...                 T                 C
# ALT                           G  ...                 C                 T
# Mutation Name chr1:349253:.:A:G  ... chr9:817567:.:T:C chr9:831911:.:C:T
# Targeted                    Yes  ...               Yes               Yes
# D10-DRC-17                  1.0  ...               1.0               1.0
# D10-DRC-11                  1.0  ...               1.0               1.0
# D10-JJJ-62                  1.0  ...               1.0               1.0
# D10-JJJ-41                  1.0  ...               1.0               1.0
# D10-JJJ-56                  1.0  ...               1.0               1.0
#
# CHROM                                                          \
# POS                    850753          850754          850756
# REF                         C               A               A
# ALT                         A               G               C
# Mutation Name chr9:850753:C:A chr9:850754:A:G chr9:850756:A:C
# Targeted                   No              No              No
# D10-DRC-17                1.0             1.0             1.0
# D10-DRC-11                1.0             1.0             1.0
# D10-JJJ-62                1.0             1.0             1.0
# D10-JJJ-41                1.0             1.0             1.0
# D10-JJJ-56                1.0             1.0             1.0
#
# CHROM                                                            \
# POS                      917264          95529            95530
# REF                           A              C                T
# ALT                           G              A                A
# Mutation Name chr9:917264:.:A:G chr9:95529:C:A chr9:95530:.:T:A
# Targeted                    Yes             No              Yes
# D10-DRC-17                  0.0            1.0              1.0
# D10-DRC-11                  0.0            1.0              1.0
# D10-JJJ-62                  1.0            1.0              1.0
# D10-JJJ-41                  1.0            1.0              1.0
# D10-JJJ-56                  1.0            1.0              1.0
#
# CHROM
# POS                      963651          963670
# REF                           C               G
# ALT                           T               C
# Mutation Name chr9:963651:.:C:T chr9:963670:G:C
# Targeted                    Yes              No
# D10-DRC-17                  1.0             0.0
# D10-DRC-11                  NaN             NaN
# D10-JJJ-62                  1.0             1.0
# D10-JJJ-41                  1.0             1.0
# D10-JJJ-56                  1.0             0.0
#
# [5 rows x 1194 columns]

# %% [markdown]
# RealMcCoil uses 0, 0.5, 1 and -1 for homozygous reference, mixed, homozygous alternate and missing genotypes, respectively. Below we'll divide the values of our table by 2 and fill the missing values with -1.

# %%
mccoil_genotypes = (genotypes/2).fillna(-1)

# %% [markdown]
# Import rpy2.ipython module to run some **R** code within this notebook.

# %%
# %load_ext rpy2.ipython

# %% [markdown]
# Below cell starts with %%R, meaning the entire cell content is interpreted in R language. We can provide the genotype table, which is in python format, to the R code using -i in the first line. Similarly, with -o, we can get the output of the McCoil R object in python form to use downstream.
#
# RealMcCOIL also creates the specified file (output_15.txt, in this case) but we will not use it here. The cell below is only an example. Use the parameters appropriate for your data but these settings should be suitable for most MIP data with enough iterations (2000) and starting and maximum COI (15 and 25, respectively).

# %%
# %%R -i mccoil_genotypes -o out_cat
# library(McCOILR)
# library(Rcpp)
# starting_coi <- 15
# out_cat <- McCOIL_categorical(mccoil_genotypes,maxCOI=25, totalrun=2000, burnin=500,
#                             M0=starting_coi, err_method=3,
#                             path="mcoil_output",
#                             output=paste0("output_", starting_coi,
#                                           ".txt" ))
# Out:
# Time = 49.00 s

# %% [markdown]
# Check the output

# %%
out_cat
# Out:
#                file CorP                                               name  \
# 1     output_15.txt    C                                         D10-DRC-17
# 2     output_15.txt    C                                         D10-DRC-11
# 3     output_15.txt    C                                         D10-JJJ-62
# 4     output_15.txt    C                                         D10-JJJ-41
# 5     output_15.txt    C                                         D10-JJJ-56
# ...             ...  ...                                                ...
# 1746  output_15.txt    P  ('chr9', '95530', 'T', 'A', 'chr9:95530:.:T:A'...
# 1747  output_15.txt    P  ('chr9', '963651', 'C', 'T', 'chr9:963651:.:C:...
# 1748  output_15.txt    P  ('chr9', '963670', 'G', 'C', 'chr9:963670:G:C'...
# 1749  output_15.txt   e1                                                 e1
# 1750  output_15.txt   e2                                                 e2
#
#            mean     median       sd  quantile0.025  quantile0.975
# 1      5.000000   5.000000  0.13302       5.000000       5.000000
# 2      6.000000   6.000000  0.30799       5.000000       6.000000
# 3     21.000000  21.000000  1.24320      19.000000      24.000000
# 4     18.000000  18.000000  1.02714      16.000000      20.000000
# 5      7.000000   7.000000  0.31429       7.000000       8.000000
# ...         ...        ...      ...            ...            ...
# 1746   0.506195   0.503596  0.09898       0.320321       0.699479
# 1747   0.242574   0.238454  0.05417       0.157902       0.366651
# 1748   0.028849   0.027717  0.00827       0.016935       0.048962
# 1749   0.003506   0.003452  0.00180       0.000314       0.007023
# 1750   0.012638   0.011515  0.00249       0.010103       0.019001
#
# [1750 rows x 8 columns]

# %% [markdown]
# COI calls can be selected using the CorP column (it is C for the COI calls). The rest of the table describes statistics for the variants etc.
#
# The **mean** and **median** columns show the mean and median COI values for the sample across the iterations.

# %%
coi_calls = out_cat.loc[out_cat["CorP"] == "C"]
coi_calls.shape
# Out:
# (41, 8)

# %%
coi_calls
# Out:
#              file CorP        name  mean  median       sd  quantile0.025  \
# 1   output_15.txt    C  D10-DRC-17   5.0     5.0  0.04470          5.000
# 2   output_15.txt    C  D10-DRC-11   5.0     5.0  0.46021          5.000
# 3   output_15.txt    C  D10-JJJ-62  24.0    24.0  1.08739         21.000
# 4   output_15.txt    C  D10-JJJ-41  21.0    20.0  1.39506         18.000
# 5   output_15.txt    C  D10-JJJ-56   7.0     7.0  0.14806          7.000
# 6   output_15.txt    C  D10-JJJ-49  20.0    20.0  1.29324         18.000
# 7   output_15.txt    C   D10-DRC-9   6.0     6.0  0.08913          6.000
# 8   output_15.txt    C  D10-JJJ-34  19.0    19.0  1.28601         17.000
# 9   output_15.txt    C  D10-JJJ-40  21.0    21.0  1.39645         19.000
# 10  output_15.txt    C  D10-JJJ-36  22.0    22.0  1.26082         20.000
# 11  output_15.txt    C  D10-JJJ-61   7.0     7.0  0.13026          7.000
# 12  output_15.txt    C  D10-JJJ-27  20.0    20.0  1.24485         18.000
# 13  output_15.txt    C  D10-DRC-15  11.0    11.0  0.63083         10.000
# 14  output_15.txt    C  D10-JJJ-35  23.0    24.0  1.25397         21.000
# 15  output_15.txt    C  D10-JJJ-84  22.0    22.0  1.41109         20.000
# 16  output_15.txt    C  D10-JJJ-28  21.0    21.0  1.23219         18.000
# 17  output_15.txt    C  D10-JJJ-50  19.0    19.0  1.15921         17.000
# 18  output_15.txt    C  D10-JJJ-31  23.0    23.0  1.27228         20.975
# 19  output_15.txt    C  D10-JJJ-82   6.0     6.0  0.41580          6.000
# 20  output_15.txt    C  D10-JJJ-25  18.0    17.0  1.06055         16.000
# 21  output_15.txt    C  D10-JJJ-60  11.0    11.0  0.59334         10.000
# 22  output_15.txt    C  D10-JJJ-29  19.0    19.0  1.26859         17.000
# 23  output_15.txt    C  D10-JJJ-83  23.0    23.0  1.25835         21.000
# 24  output_15.txt    C  D10-DRC-19   5.0     5.0  0.00000          5.000
# 25  output_15.txt    C  D10-JJJ-58  17.0    17.0  1.14039         16.000
# 26  output_15.txt    C  D10-JJJ-30  23.0    23.0  1.28784         20.000
# 27  output_15.txt    C  D10-JJJ-22   7.0     7.0  0.30544          6.000
# 28  output_15.txt    C  D10-DRC-13  12.0    12.0  0.74802         11.000
# 29  output_15.txt    C  D10-JJJ-42   5.0     5.0  0.00000          5.000
# 30  output_15.txt    C  D10-JJJ-52  18.0    18.0  1.04971         16.000
# 31  output_15.txt    C  D10-JJJ-44   4.0     4.0  0.00000          4.000
# 32  output_15.txt    C  D10-JJJ-38  18.0    18.0  1.27221         16.000
# 33  output_15.txt    C  D10-JJJ-24   7.0     7.0  0.21685          6.000
# 34  output_15.txt    C  D10-JJJ-23  21.0    21.0  1.29418         19.000
# 35  output_15.txt    C  D10-JJJ-51  18.0    18.0  1.10680         16.000
# 36  output_15.txt    C  D10-JJJ-26  23.0    23.0  1.26380         21.000
# 37  output_15.txt    C   D10-DRC-2   6.0     6.0  0.37757          6.000
# 38  output_15.txt    C  D10-JJJ-37  24.0    24.0  1.02988         22.000
# 39  output_15.txt    C  D10-JJJ-33  25.0    25.0  0.64683         23.000
# 40  output_15.txt    C  D10-JJJ-39  15.0    15.0  0.82751         13.000
# 41  output_15.txt    C  D10-JJJ-48   4.0     4.0  0.00000          4.000
#
#     quantile0.975
# 1             5.0
# 2             6.0
# 3            25.0
# 4            23.0
# 5             7.0
# 6            23.0
# 7             6.0
# 8            22.0
# 9            24.0
# 10           24.0
# 11            7.0
# 12           23.0
# 13           12.0
# 14           25.0
# 15           25.0
# 16           23.0
# 17           21.0
# 18           25.0
# 19            7.0
# 20           20.0
# 21           12.0
# 22           22.0
# 23           25.0
# 24            5.0
# 25           20.0
# 26           25.0
# 27            7.0
# 28           14.0
# 29            5.0
# 30           20.0
# 31            4.0
# 32           21.0
# 33            7.0
# 34           24.0
# 35           20.0
# 36           25.0
# 37            7.0
# 38           25.0
# 39           25.0
# 40           16.0
# 41            4.0

# %% [markdown]
# Save the COI values to file

# %%
coi_calls.to_csv("COI_calls.csv")
