# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# ## Code visibility
# Use the Show/Hide Code button on the top left to make to make the code visible or hide it. It will be hidden in the HTML files by default.

# %%
# RUN
import sys
sys.path.append("/opt/src")
import mip_functions as mip
import pickle
import json
import copy
import os
import numpy as np
import subprocess
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from wrangler_stats import get_stats
wdir = "/opt/analysis/"
data_dir = "/opt/data/"
# Out:
# Classes reloading.
# functions reloading

# %% [markdown]
# After each MIPWrangler run, 3 statistics files are generated. These are useful to understand how a sequencing run or processing performed. These files will be located in the wrangler directory. Their names may be slightly different depending on the miptools version (names may contain date information, may or may not be zipped etc.)
#
# For the test analysis run, I used the path binding wrangler_dir to /opt/data when I started this notebook, so the file paths below reflect that.

# %% [markdown]
# ## Numbers for read extraction from fastq files

# %%
extraction_summary_file = "/opt/data/extractInfoSummary.txt.gz"
extraction = get_stats(extraction_summary_file)

# %%
extraction.head()
# Out:
#        Sample  total  unmatched  indeterminate  smallFragment  totalMatched  \
# 0  D10-JJJ-47   7049       2965              0              0          4084
# 2  D10-JJJ-48   6820       3162              0              0          3658
# 4  D10-JJJ-20      1          1              0              0             0
# 6  D10-JJJ-11    216        130              0              0            86
# 8  D10-JJJ-37  26897       1720              0              0         25177
#
#    goodReads  failedLigationArm  failedMinLen(<30)  failed_q30<0.75  \
# 0         83                  4                  0                1
# 2        120                  3                  0                1
# 4          0                  0                  0                0
# 6          1                  0                  0                2
# 8      21407                393                  0              946
#
#    containsNs  badStitch
# 0           0       3996
# 2           0       3534
# 4           0          0
# 6           0         83
# 8           6       2425

# %% [markdown]
# Explanation of important field names for the extractInfoSummary file (all numbers show number of reads for that sample:
# *  total: number of total reads for the sample
# *  totalMatched: reads that had a proper extension arm sequence
# *  failedLigationArm: reads that did not have the matching ligation arm sequence
# *  badStitch: read pairs that did not stitch properly
# *  goodReads: reads used downstream

# %% [markdown]
# Get total numbers for each field

# %%
extraction.sum(numeric_only=True).sort_values(ascending=False)
# Out:
# total                643615
# totalMatched         544671
# goodReads            436599
# unmatched             98944
# badStitch             85658
# failed_q30<0.75       15235
# failedLigationArm      7039
# containsNs              140
# failedMinLen(<30)         0
# smallFragment             0
# indeterminate             0
# dtype: int64

# %% [markdown]
# Same statistic in fraction of total:

# %%
extraction.sum(numeric_only=True).div(extraction.sum(numeric_only=True)["total"], axis=0).sort_values(
    ascending=False)
# Out:
# total                1.000000
# totalMatched         0.846268
# goodReads            0.678354
# unmatched            0.153732
# badStitch            0.133089
# failed_q30<0.75      0.023671
# failedLigationArm    0.010937
# containsNs           0.000218
# failedMinLen(<30)    0.000000
# smallFragment        0.000000
# indeterminate        0.000000
# dtype: float64

# %% [markdown]
# 67.8% of the reads will be used in clustering

# %% [markdown]
# ## Numbers for forward and reverse read stitching

# %%
# Load the stitching info file
stitch_file = "/opt/data/stitchInfoByTarget.txt.gz"
sti = get_stats(stitch_file)
sti.head()
# Out:
#        Sample                        mipTarget                    mipFamily  \
# 0  D10-JJJ-47   PF3D7-1322700_S0_Sub0_mip0_ref   PF3D7-1322700_S0_Sub0_mip0
# 1  D10-JJJ-47  PF3D7-1451200_S0_Sub0_mip14_ref  PF3D7-1451200_S0_Sub0_mip14
# 2  D10-JJJ-47            ama1_S0_Sub0_mip0_ref            ama1_S0_Sub0_mip0
# 3  D10-JJJ-47            ama1_S0_Sub0_mip1_ref            ama1_S0_Sub0_mip1
# 4  D10-JJJ-47            ama1_S0_Sub0_mip2_ref            ama1_S0_Sub0_mip2
#
#    total  r1EndsInR2  r1BeginsInR2  OverlapFail  PerfectOverlap
# 0     12           0             8            4               0
# 1      6           0             6            0               0
# 2     93           4            89            0               0
# 3      3           0             3            0               0
# 4    112           0           111            1               0

# %% [markdown]
# The stitching info file has one line per mip per sample and 5 data columns:
#   * **total**: Total number of reads for that sample/mip combination.
#   * **r1EndsInR2**: Number of reads that properly stitched.
#   * **r2BeginsInR2**: Indicates primer/adapter dimers or small junk sequence.
#   * **OverlapFail**: No high quality overlap was found. This could mean the sequences were low quality, or there was not enough overlap, for example if the captured region is 500 bp but we sequenced 150 bp paired end sequencing. Another example is when there is a big enough insertion in the captured region, the reads do not overlap.
#   *  **PerfectOverlap**: Unlikely scenario that two reads perfectly overlap.
#
# Only the **r1EndsInR2** and **PerfectOverlap** reads are used for the rest of the pipeline.

# %% [markdown]
# Let's look at the total number of each category.

# %%
sti.sum(numeric_only=True).sort_values(ascending=False)
# Out:
# total             544671
# r1EndsInR2        459013
# r1BeginsInR2       44323
# OverlapFail        41334
# PerfectOverlap         1
# dtype: int64

# %% [markdown]
# Out of 544671 reads, 459013 stiched fine.
# Let's look at them in terms of fraction of total.

# %%
sti.sum(numeric_only=True).div(sti.sum(numeric_only=True)["total"], axis=0).sort_values(ascending=False)
# Out:
# total             1.000000
# r1EndsInR2        0.842734
# r1BeginsInR2      0.081376
# OverlapFail       0.075888
# PerfectOverlap    0.000002
# dtype: float64

# %% [markdown]
# 84% of the reads are fine and will be used for the next steps in the pipeline.
#
# We can also look at the stats per MIP to have an idea which MIPs are performing good or bad. If certain MIPs have increased failure, it could warrant some attention.

# %%
sti.groupby("mipTarget").sum(numeric_only=True).sort_values("r1EndsInR2", ascending=False)
# Out:
#                                  total  r1EndsInR2  r1BeginsInR2  OverlapFail  \
# mipTarget
# crt_S0_Sub0_mip1_ref             49519       47344           789         1386
# crt_S0_Sub0_mip0_ref             33161       30921          1448          792
# win42_S0_Sub0_mip1_ref           30226       28811           128         1287
# dhfr-ts_S0_Sub0_mip0_ref         22783       21366           602          815
# cytb_S0_Sub0_mip3                21872       20418            29         1425
# atp6_S0_Sub0_mip12               18973       17938           140          895
# crt_S0_Sub2_mip6_ref             46099       17387         23021         5691
# csp_S0_Sub0_mip1                 16531       15166           510          854
# atp6_S0_Sub0_mip10               16342       15030           270         1042
# win24_S0_Sub0_mip0_ref           16116       14606           898          612
# win54_S0_Sub0_mip0_ref           14078       13533           161          384
# csp_S0_Sub0_mip3                 14206       13276            87          843
# ama1_S0_Sub0_mip6_ref            13539       12515           529          495
# mdr1_S0_Sub0_mip12               10392        9909           131          352
# ama1_S0_Sub0_mip3_ref             9797        9291           138          368
# atp6_S0_Sub0_mip11               10036        9227           154          655
# ama1_S0_Sub0_mip2_ref            10655        9008          1391          256
# cytb_S0_Sub0_mip2                 9018        8638            22          358
# k13_S0_Sub0_mip1_ref              8816        8455            86          275
# ama1_S0_Sub0_mip4_ref             9377        8314           311          752
# ama1_S0_Sub0_mip5_ref             8637        8104           131          402
# atp6_S0_Sub0_mip8                 8653        7961           157          535
# mdr1_S0_Sub0_mip3                 8638        7588           166          884
# mdr1_S0_Sub0_mip1                 7133        6784           130          219
# ama1_S0_Sub0_mip0_ref             8384        6767          1195          422
# dhfr-ts_S0_Sub0_mip2              6996        6622           147          227
# k13_S0_Sub0_mip5_ref              6157        5879            67          211
# atp6_S0_Sub0_mip7                 6241        5702           107          432
# dhps_S0_Sub0_mip5                 6587        5283           125         1179
# atp6_S0_Sub0_mip9                 5403        4836           182          385
# ama1_S0_Sub0_mip1_ref             5096        4719           160          217
# dhps_S0_Sub0_mip6                 5636        4536           370          730
# k13_S0_Sub0_mip2_ref              4681        4306           251          124
# nhe_S0_Sub0_mip0                  8208        4214           267         3727
# mdr1_S0_Sub0_mip13                4480        4091           167          222
# arps10_S0_Sub0_mip2_ref           4501        4088            38          375
# k13_S0_Sub0_mip7_ref              4343        3967           208          168
# k13_S0_Sub0_mip4_ref              4082        3902            37          143
# PF3D7-1451200_S0_Sub0_mip14_ref   3975        3624            97          254
# k13_S0_Sub0_mip6_ref              3419        3126           143          150
# fd_S0_Sub0_mip0_ref               3269        3073            94          102
# k13_S0_Sub0_mip3_ref              3313        2998            55          260
# mdr2_S0_Sub0_mip5_ref             2926        2678            48          200
# pph_S0_Sub0_mip11_ref             2703        2522           102           79
# mdr1_S0_Sub0_mip2                 2580        2366           110          104
# dhfr-ts_S0_Sub0_mip3              2511        2113           211          187
# k13_S0_Sub0_mip8_ref              2816        1843           442          531
# pib7_S0_Sub1_mip13_ref            3099        1289          1712           98
# atp6_S0_Sub0_mip6                 1233        1098            72           63
# crt_S0_Sub2_mip4_ref              1412         522           636          254
# crt_S0_Sub2_mip5_ref              1207         396           701          110
# PF3D7-1322700_S0_Sub0_mip0_ref    7848         353           150         7345
# crt_S0_Sub1_mip3_ref              1766         194          1400          172
# k13_S0_Sub0_mip0_ref               895         168            65          662
# crt_S0_Sub1_mip2_ref              1820         139          1125          556
# crt-dup_S0_Sub0_mip0_ref          2485           9          2408           68
# crt-dup_S0_Sub0_mip1_ref             2           0             2            0
#
#                                  PerfectOverlap
# mipTarget
# crt_S0_Sub0_mip1_ref                          0
# crt_S0_Sub0_mip0_ref                          0
# win42_S0_Sub0_mip1_ref                        0
# dhfr-ts_S0_Sub0_mip0_ref                      0
# cytb_S0_Sub0_mip3                             0
# atp6_S0_Sub0_mip12                            0
# crt_S0_Sub2_mip6_ref                          0
# csp_S0_Sub0_mip1                              1
# atp6_S0_Sub0_mip10                            0
# win24_S0_Sub0_mip0_ref                        0
# win54_S0_Sub0_mip0_ref                        0
# csp_S0_Sub0_mip3                              0
# ama1_S0_Sub0_mip6_ref                         0
# mdr1_S0_Sub0_mip12                            0
# ama1_S0_Sub0_mip3_ref                         0
# atp6_S0_Sub0_mip11                            0
# ama1_S0_Sub0_mip2_ref                         0
# cytb_S0_Sub0_mip2                             0
# k13_S0_Sub0_mip1_ref                          0
# ama1_S0_Sub0_mip4_ref                         0
# ama1_S0_Sub0_mip5_ref                         0
# atp6_S0_Sub0_mip8                             0
# mdr1_S0_Sub0_mip3                             0
# mdr1_S0_Sub0_mip1                             0
# ama1_S0_Sub0_mip0_ref                         0
# dhfr-ts_S0_Sub0_mip2                          0
# k13_S0_Sub0_mip5_ref                          0
# atp6_S0_Sub0_mip7                             0
# dhps_S0_Sub0_mip5                             0
# atp6_S0_Sub0_mip9                             0
# ama1_S0_Sub0_mip1_ref                         0
# dhps_S0_Sub0_mip6                             0
# k13_S0_Sub0_mip2_ref                          0
# nhe_S0_Sub0_mip0                              0
# mdr1_S0_Sub0_mip13                            0
# arps10_S0_Sub0_mip2_ref                       0
# k13_S0_Sub0_mip7_ref                          0
# k13_S0_Sub0_mip4_ref                          0
# PF3D7-1451200_S0_Sub0_mip14_ref               0
# k13_S0_Sub0_mip6_ref                          0
# fd_S0_Sub0_mip0_ref                           0
# k13_S0_Sub0_mip3_ref                          0
# mdr2_S0_Sub0_mip5_ref                         0
# pph_S0_Sub0_mip11_ref                         0
# mdr1_S0_Sub0_mip2                             0
# dhfr-ts_S0_Sub0_mip3                          0
# k13_S0_Sub0_mip8_ref                          0
# pib7_S0_Sub1_mip13_ref                        0
# atp6_S0_Sub0_mip6                             0
# crt_S0_Sub2_mip4_ref                          0
# crt_S0_Sub2_mip5_ref                          0
# PF3D7-1322700_S0_Sub0_mip0_ref                0
# crt_S0_Sub1_mip3_ref                          0
# k13_S0_Sub0_mip0_ref                          0
# crt_S0_Sub1_mip2_ref                          0
# crt-dup_S0_Sub0_mip0_ref                      0
# crt-dup_S0_Sub0_mip1_ref                      0

# %%
sti.groupby("mipTarget").sum(numeric_only=True).div(sti.groupby("mipTarget").sum(numeric_only=True)["total"],
                                                   axis=0).sort_values("r1EndsInR2", ascending=False)
# Out:
#                                  total  r1EndsInR2  r1BeginsInR2  OverlapFail  \
# mipTarget
# win54_S0_Sub0_mip0_ref             1.0    0.961287      0.011436     0.027277
# k13_S0_Sub0_mip1_ref               1.0    0.959052      0.009755     0.031193
# cytb_S0_Sub0_mip2                  1.0    0.957862      0.002440     0.039698
# crt_S0_Sub0_mip1_ref               1.0    0.956077      0.015933     0.027989
# k13_S0_Sub0_mip4_ref               1.0    0.955904      0.009064     0.035032
# k13_S0_Sub0_mip5_ref               1.0    0.954848      0.010882     0.034270
# mdr1_S0_Sub0_mip12                 1.0    0.953522      0.012606     0.033872
# win42_S0_Sub0_mip1_ref             1.0    0.953186      0.004235     0.042579
# mdr1_S0_Sub0_mip1                  1.0    0.951072      0.018225     0.030702
# ama1_S0_Sub0_mip3_ref              1.0    0.948352      0.014086     0.037563
# dhfr-ts_S0_Sub0_mip2               1.0    0.946541      0.021012     0.032447
# atp6_S0_Sub0_mip12                 1.0    0.945449      0.007379     0.047172
# fd_S0_Sub0_mip0_ref                1.0    0.940043      0.028755     0.031202
# ama1_S0_Sub0_mip5_ref              1.0    0.938289      0.015167     0.046544
# dhfr-ts_S0_Sub0_mip0_ref           1.0    0.937805      0.026423     0.035772
# csp_S0_Sub0_mip3                   1.0    0.934535      0.006124     0.059341
# cytb_S0_Sub0_mip3                  1.0    0.933522      0.001326     0.065152
# pph_S0_Sub0_mip11_ref              1.0    0.933037      0.037736     0.029227
# crt_S0_Sub0_mip0_ref               1.0    0.932451      0.043666     0.023883
# ama1_S0_Sub0_mip1_ref              1.0    0.926020      0.031397     0.042582
# ama1_S0_Sub0_mip6_ref              1.0    0.924367      0.039072     0.036561
# atp6_S0_Sub0_mip8                  1.0    0.920028      0.018144     0.061828
# k13_S0_Sub0_mip2_ref               1.0    0.919889      0.053621     0.026490
# atp6_S0_Sub0_mip10                 1.0    0.919716      0.016522     0.063762
# atp6_S0_Sub0_mip11                 1.0    0.919390      0.015345     0.065265
# csp_S0_Sub0_mip1                   1.0    0.917428      0.030851     0.051661
# mdr1_S0_Sub0_mip2                  1.0    0.917054      0.042636     0.040310
# mdr2_S0_Sub0_mip5_ref              1.0    0.915243      0.016405     0.068353
# k13_S0_Sub0_mip6_ref               1.0    0.914302      0.041825     0.043872
# atp6_S0_Sub0_mip7                  1.0    0.913636      0.017145     0.069220
# k13_S0_Sub0_mip7_ref               1.0    0.913424      0.047893     0.038683
# mdr1_S0_Sub0_mip13                 1.0    0.913170      0.037277     0.049554
# PF3D7-1451200_S0_Sub0_mip14_ref    1.0    0.911698      0.024403     0.063899
# arps10_S0_Sub0_mip2_ref            1.0    0.908243      0.008443     0.083315
# win24_S0_Sub0_mip0_ref             1.0    0.906304      0.055721     0.037975
# k13_S0_Sub0_mip3_ref               1.0    0.904920      0.016601     0.078479
# atp6_S0_Sub0_mip9                  1.0    0.895058      0.033685     0.071257
# atp6_S0_Sub0_mip6                  1.0    0.890511      0.058394     0.051095
# ama1_S0_Sub0_mip4_ref              1.0    0.886638      0.033166     0.080196
# mdr1_S0_Sub0_mip3                  1.0    0.878444      0.019217     0.102339
# ama1_S0_Sub0_mip2_ref              1.0    0.845425      0.130549     0.024026
# dhfr-ts_S0_Sub0_mip3               1.0    0.841497      0.084030     0.074472
# ama1_S0_Sub0_mip0_ref              1.0    0.807133      0.142533     0.050334
# dhps_S0_Sub0_mip6                  1.0    0.804826      0.065649     0.129524
# dhps_S0_Sub0_mip5                  1.0    0.802034      0.018977     0.178989
# k13_S0_Sub0_mip8_ref               1.0    0.654474      0.156960     0.188565
# nhe_S0_Sub0_mip0                   1.0    0.513402      0.032529     0.454069
# pib7_S0_Sub1_mip13_ref             1.0    0.415941      0.552436     0.031623
# crt_S0_Sub2_mip6_ref               1.0    0.377167      0.499382     0.123452
# crt_S0_Sub2_mip4_ref               1.0    0.369688      0.450425     0.179887
# crt_S0_Sub2_mip5_ref               1.0    0.328086      0.580779     0.091135
# k13_S0_Sub0_mip0_ref               1.0    0.187709      0.072626     0.739665
# crt_S0_Sub1_mip3_ref               1.0    0.109853      0.792752     0.097395
# crt_S0_Sub1_mip2_ref               1.0    0.076374      0.618132     0.305495
# PF3D7-1322700_S0_Sub0_mip0_ref     1.0    0.044980      0.019113     0.935907
# crt-dup_S0_Sub0_mip0_ref           1.0    0.003622      0.969014     0.027364
# crt-dup_S0_Sub0_mip1_ref           1.0    0.000000      1.000000     0.000000
#
#                                  PerfectOverlap
# mipTarget
# win54_S0_Sub0_mip0_ref                  0.00000
# k13_S0_Sub0_mip1_ref                    0.00000
# cytb_S0_Sub0_mip2                       0.00000
# crt_S0_Sub0_mip1_ref                    0.00000
# k13_S0_Sub0_mip4_ref                    0.00000
# k13_S0_Sub0_mip5_ref                    0.00000
# mdr1_S0_Sub0_mip12                      0.00000
# win42_S0_Sub0_mip1_ref                  0.00000
# mdr1_S0_Sub0_mip1                       0.00000
# ama1_S0_Sub0_mip3_ref                   0.00000
# dhfr-ts_S0_Sub0_mip2                    0.00000
# atp6_S0_Sub0_mip12                      0.00000
# fd_S0_Sub0_mip0_ref                     0.00000
# ama1_S0_Sub0_mip5_ref                   0.00000
# dhfr-ts_S0_Sub0_mip0_ref                0.00000
# csp_S0_Sub0_mip3                        0.00000
# cytb_S0_Sub0_mip3                       0.00000
# pph_S0_Sub0_mip11_ref                   0.00000
# crt_S0_Sub0_mip0_ref                    0.00000
# ama1_S0_Sub0_mip1_ref                   0.00000
# ama1_S0_Sub0_mip6_ref                   0.00000
# atp6_S0_Sub0_mip8                       0.00000
# k13_S0_Sub0_mip2_ref                    0.00000
# atp6_S0_Sub0_mip10                      0.00000
# atp6_S0_Sub0_mip11                      0.00000
# csp_S0_Sub0_mip1                        0.00006
# mdr1_S0_Sub0_mip2                       0.00000
# mdr2_S0_Sub0_mip5_ref                   0.00000
# k13_S0_Sub0_mip6_ref                    0.00000
# atp6_S0_Sub0_mip7                       0.00000
# k13_S0_Sub0_mip7_ref                    0.00000
# mdr1_S0_Sub0_mip13                      0.00000
# PF3D7-1451200_S0_Sub0_mip14_ref         0.00000
# arps10_S0_Sub0_mip2_ref                 0.00000
# win24_S0_Sub0_mip0_ref                  0.00000
# k13_S0_Sub0_mip3_ref                    0.00000
# atp6_S0_Sub0_mip9                       0.00000
# atp6_S0_Sub0_mip6                       0.00000
# ama1_S0_Sub0_mip4_ref                   0.00000
# mdr1_S0_Sub0_mip3                       0.00000
# ama1_S0_Sub0_mip2_ref                   0.00000
# dhfr-ts_S0_Sub0_mip3                    0.00000
# ama1_S0_Sub0_mip0_ref                   0.00000
# dhps_S0_Sub0_mip6                       0.00000
# dhps_S0_Sub0_mip5                       0.00000
# k13_S0_Sub0_mip8_ref                    0.00000
# nhe_S0_Sub0_mip0                        0.00000
# pib7_S0_Sub1_mip13_ref                  0.00000
# crt_S0_Sub2_mip6_ref                    0.00000
# crt_S0_Sub2_mip4_ref                    0.00000
# crt_S0_Sub2_mip5_ref                    0.00000
# k13_S0_Sub0_mip0_ref                    0.00000
# crt_S0_Sub1_mip3_ref                    0.00000
# crt_S0_Sub1_mip2_ref                    0.00000
# PF3D7-1322700_S0_Sub0_mip0_ref          0.00000
# crt-dup_S0_Sub0_mip0_ref                0.00000
# crt-dup_S0_Sub0_mip1_ref                0.00000

# %% [markdown]
# ## Extraction statistics per sample per probe

# %%
extraction_by_target = "/opt/data/extractInfoByTarget.txt.gz"
ext_by_target = get_stats(extraction_by_target)
ext_by_target.head()
# Out:
#        Sample                        mipTarget                    mipFamily  \
# 0  D10-JJJ-47   PF3D7-1322700_S0_Sub0_mip0_ref   PF3D7-1322700_S0_Sub0_mip0
# 1  D10-JJJ-47  PF3D7-1451200_S0_Sub0_mip14_ref  PF3D7-1451200_S0_Sub0_mip14
# 2  D10-JJJ-47            ama1_S0_Sub0_mip0_ref            ama1_S0_Sub0_mip0
# 3  D10-JJJ-47            ama1_S0_Sub0_mip1_ref            ama1_S0_Sub0_mip1
# 4  D10-JJJ-47            ama1_S0_Sub0_mip2_ref            ama1_S0_Sub0_mip2
#
#    totalMatched  goodReads  failedLigationArm  failedMinLen(<30)  \
# 0            12          0                  0                  0
# 1             6          0                  0                  0
# 2            93          4                  0                  0
# 3             3          0                  0                  0
# 4           112          0                  0                  0
#
#    failed_q30<0.75  containsNs  badStitch
# 0                0           0         12
# 1                0           0          6
# 2                0           0         89
# 3                0           0          3
# 4                0           0        112

# %%
ext_by_target.groupby("mipTarget").sum(numeric_only=True).div(
    ext_by_target.groupby("mipTarget").sum(
        numeric_only=True)["totalMatched"], axis=0).sort_values("goodReads", ascending=False)
# Out:
#                                  totalMatched  goodReads  failedLigationArm  \
# mipTarget
# crt_S0_Sub0_mip1_ref                      1.0   0.944708           0.010743
# mdr1_S0_Sub0_mip12                        1.0   0.923691           0.010585
# k13_S0_Sub0_mip4_ref                      1.0   0.921852           0.014454
# win54_S0_Sub0_mip0_ref                    1.0   0.919165           0.012928
# cytb_S0_Sub0_mip2                         1.0   0.916057           0.012087
# crt_S0_Sub0_mip0_ref                      1.0   0.915503           0.016345
# atp6_S0_Sub0_mip12                        1.0   0.914247           0.011121
# dhfr-ts_S0_Sub0_mip2                      1.0   0.906518           0.012150
# win42_S0_Sub0_mip1_ref                    1.0   0.906372           0.013399
# cytb_S0_Sub0_mip3                         1.0   0.896900           0.019706
# mdr1_S0_Sub0_mip1                         1.0   0.889948           0.011776
# k13_S0_Sub0_mip1_ref                      1.0   0.886343           0.009642
# csp_S0_Sub0_mip3                          1.0   0.882937           0.012037
# atp6_S0_Sub0_mip10                        1.0   0.877861           0.010525
# k13_S0_Sub0_mip5_ref                      1.0   0.877700           0.010720
# dhfr-ts_S0_Sub0_mip0_ref                  1.0   0.877189           0.016240
# csp_S0_Sub0_mip1                          1.0   0.875930           0.019297
# ama1_S0_Sub0_mip3_ref                     1.0   0.874860           0.012657
# atp6_S0_Sub0_mip11                        1.0   0.873356           0.011758
# k13_S0_Sub0_mip7_ref                      1.0   0.871978           0.008750
# PF3D7-1451200_S0_Sub0_mip14_ref           1.0   0.871950           0.018365
# mdr1_S0_Sub0_mip13                        1.0   0.868304           0.022321
# mdr1_S0_Sub0_mip2                         1.0   0.867442           0.004264
# ama1_S0_Sub0_mip5_ref                     1.0   0.863842           0.011810
# arps10_S0_Sub0_mip2_ref                   1.0   0.863364           0.013108
# ama1_S0_Sub0_mip1_ref                     1.0   0.859890           0.007064
# mdr2_S0_Sub0_mip5_ref                     1.0   0.859193           0.019481
# pph_S0_Sub0_mip11_ref                     1.0   0.859046           0.018128
# win24_S0_Sub0_mip0_ref                    1.0   0.858277           0.016878
# ama1_S0_Sub0_mip6_ref                     1.0   0.857966           0.015068
# k13_S0_Sub0_mip6_ref                      1.0   0.855221           0.021351
# atp6_S0_Sub0_mip8                         1.0   0.853577           0.016179
# fd_S0_Sub0_mip0_ref                       1.0   0.848272           0.018048
# atp6_S0_Sub0_mip6                         1.0   0.847526           0.012976
# k13_S0_Sub0_mip2_ref                      1.0   0.840846           0.007691
# atp6_S0_Sub0_mip9                         1.0   0.839904           0.016102
# mdr1_S0_Sub0_mip3                         1.0   0.838620           0.017712
# k13_S0_Sub0_mip3_ref                      1.0   0.838213           0.009961
# atp6_S0_Sub0_mip7                         1.0   0.833520           0.012017
# ama1_S0_Sub0_mip4_ref                     1.0   0.818919           0.021862
# dhfr-ts_S0_Sub0_mip3                      1.0   0.803664           0.013939
# ama1_S0_Sub0_mip2_ref                     1.0   0.786673           0.012295
# dhps_S0_Sub0_mip5                         1.0   0.777592           0.009564
# ama1_S0_Sub0_mip0_ref                     1.0   0.743201           0.015386
# dhps_S0_Sub0_mip6                         1.0   0.699610           0.017211
# k13_S0_Sub0_mip8_ref                      1.0   0.614347           0.011009
# nhe_S0_Sub0_mip0                          1.0   0.462110           0.007066
# pib7_S0_Sub1_mip13_ref                    1.0   0.384318           0.005486
# crt_S0_Sub2_mip6_ref                      1.0   0.368490           0.008460
# crt_S0_Sub2_mip4_ref                      1.0   0.360482           0.005666
# crt_S0_Sub2_mip5_ref                      1.0   0.325601           0.002486
# crt_S0_Sub1_mip3_ref                      1.0   0.105323           0.001699
# k13_S0_Sub0_mip0_ref                      1.0   0.088268           0.005587
# crt_S0_Sub1_mip2_ref                      1.0   0.073626           0.002747
# PF3D7-1322700_S0_Sub0_mip0_ref            1.0   0.042686           0.001274
# crt-dup_S0_Sub0_mip0_ref                  1.0   0.003219           0.000402
# crt-dup_S0_Sub0_mip1_ref                  1.0   0.000000           0.000000
#
#                                  failedMinLen(<30)  failed_q30<0.75  \
# mipTarget
# crt_S0_Sub0_mip1_ref                           0.0         0.000202
# mdr1_S0_Sub0_mip12                             0.0         0.018861
# k13_S0_Sub0_mip4_ref                           0.0         0.019598
# win54_S0_Sub0_mip0_ref                         0.0         0.029123
# cytb_S0_Sub0_mip2                              0.0         0.029718
# crt_S0_Sub0_mip0_ref                           0.0         0.000271
# atp6_S0_Sub0_mip12                             0.0         0.019818
# dhfr-ts_S0_Sub0_mip2                           0.0         0.027730
# win42_S0_Sub0_mip1_ref                         0.0         0.033150
# cytb_S0_Sub0_mip3                              0.0         0.016551
# mdr1_S0_Sub0_mip1                              0.0         0.049068
# k13_S0_Sub0_mip1_ref                           0.0         0.062840
# csp_S0_Sub0_mip3                               0.0         0.039490
# atp6_S0_Sub0_mip10                             0.0         0.031208
# k13_S0_Sub0_mip5_ref                           0.0         0.066266
# dhfr-ts_S0_Sub0_mip0_ref                       0.0         0.044068
# csp_S0_Sub0_mip1                               0.0         0.021656
# ama1_S0_Sub0_mip3_ref                          0.0         0.060733
# atp6_S0_Sub0_mip11                             0.0         0.033679
# k13_S0_Sub0_mip7_ref                           0.0         0.032006
# PF3D7-1451200_S0_Sub0_mip14_ref                0.0         0.021132
# mdr1_S0_Sub0_mip13                             0.0         0.021875
# mdr1_S0_Sub0_mip2                              0.0         0.044961
# ama1_S0_Sub0_mip5_ref                          0.0         0.062290
# arps10_S0_Sub0_mip2_ref                        0.0         0.031326
# ama1_S0_Sub0_mip1_ref                          0.0         0.058673
# mdr2_S0_Sub0_mip5_ref                          0.0         0.036569
# pph_S0_Sub0_mip11_ref                          0.0         0.055494
# win24_S0_Sub0_mip0_ref                         0.0         0.031025
# ama1_S0_Sub0_mip6_ref                          0.0         0.051038
# k13_S0_Sub0_mip6_ref                           0.0         0.037730
# atp6_S0_Sub0_mip8                              0.0         0.049925
# fd_S0_Sub0_mip0_ref                            0.0         0.073417
# atp6_S0_Sub0_mip6                              0.0         0.030008
# k13_S0_Sub0_mip2_ref                           0.0         0.071139
# atp6_S0_Sub0_mip9                              0.0         0.039052
# mdr1_S0_Sub0_mip3                              0.0         0.021533
# k13_S0_Sub0_mip3_ref                           0.0         0.056746
# atp6_S0_Sub0_mip7                              0.0         0.067778
# ama1_S0_Sub0_mip4_ref                          0.0         0.045857
# dhfr-ts_S0_Sub0_mip3                           0.0         0.023497
# ama1_S0_Sub0_mip2_ref                          0.0         0.046269
# dhps_S0_Sub0_mip5                              0.0         0.014878
# ama1_S0_Sub0_mip0_ref                          0.0         0.048068
# dhps_S0_Sub0_mip6                              0.0         0.088006
# k13_S0_Sub0_mip8_ref                           0.0         0.029119
# nhe_S0_Sub0_mip0                               0.0         0.044225
# pib7_S0_Sub1_mip13_ref                         0.0         0.026137
# crt_S0_Sub2_mip6_ref                           0.0         0.000022
# crt_S0_Sub2_mip4_ref                           0.0         0.003541
# crt_S0_Sub2_mip5_ref                           0.0         0.000000
# crt_S0_Sub1_mip3_ref                           0.0         0.002831
# k13_S0_Sub0_mip0_ref                           0.0         0.093855
# crt_S0_Sub1_mip2_ref                           0.0         0.000000
# PF3D7-1322700_S0_Sub0_mip0_ref                 0.0         0.001019
# crt-dup_S0_Sub0_mip0_ref                       0.0         0.000000
# crt-dup_S0_Sub0_mip1_ref                       0.0         0.000000
#
#                                  containsNs  badStitch
# mipTarget
# crt_S0_Sub0_mip1_ref               0.000424   0.043923
# mdr1_S0_Sub0_mip12                 0.000385   0.046478
# k13_S0_Sub0_mip4_ref               0.000000   0.044096
# win54_S0_Sub0_mip0_ref             0.000071   0.038713
# cytb_S0_Sub0_mip2                  0.000000   0.042138
# crt_S0_Sub0_mip0_ref               0.000332   0.067549
# atp6_S0_Sub0_mip12                 0.000264   0.054551
# dhfr-ts_S0_Sub0_mip2               0.000143   0.053459
# win42_S0_Sub0_mip1_ref             0.000265   0.046814
# cytb_S0_Sub0_mip3                  0.000366   0.066478
# mdr1_S0_Sub0_mip1                  0.000280   0.048928
# k13_S0_Sub0_mip1_ref               0.000227   0.040948
# csp_S0_Sub0_mip3                   0.000070   0.065465
# atp6_S0_Sub0_mip10                 0.000122   0.080284
# k13_S0_Sub0_mip5_ref               0.000162   0.045152
# dhfr-ts_S0_Sub0_mip0_ref           0.000307   0.062195
# csp_S0_Sub0_mip1                   0.000544   0.082572
# ama1_S0_Sub0_mip3_ref              0.000102   0.051648
# atp6_S0_Sub0_mip11                 0.000598   0.080610
# k13_S0_Sub0_mip7_ref               0.000691   0.086576
# PF3D7-1451200_S0_Sub0_mip14_ref    0.000252   0.088302
# mdr1_S0_Sub0_mip13                 0.000670   0.086830
# mdr1_S0_Sub0_mip2                  0.000388   0.082946
# ama1_S0_Sub0_mip5_ref              0.000347   0.061711
# arps10_S0_Sub0_mip2_ref            0.000444   0.091757
# ama1_S0_Sub0_mip1_ref              0.000392   0.073980
# mdr2_S0_Sub0_mip5_ref              0.000000   0.084757
# pph_S0_Sub0_mip11_ref              0.000370   0.066963
# win24_S0_Sub0_mip0_ref             0.000124   0.093696
# ama1_S0_Sub0_mip6_ref              0.000295   0.075633
# k13_S0_Sub0_mip6_ref               0.000000   0.085698
# atp6_S0_Sub0_mip8                  0.000347   0.079972
# fd_S0_Sub0_mip0_ref                0.000306   0.059957
# atp6_S0_Sub0_mip6                  0.000000   0.109489
# k13_S0_Sub0_mip2_ref               0.000214   0.080111
# atp6_S0_Sub0_mip9                  0.000000   0.104942
# mdr1_S0_Sub0_mip3                  0.000579   0.121556
# k13_S0_Sub0_mip3_ref               0.000000   0.095080
# atp6_S0_Sub0_mip7                  0.000320   0.086364
# ama1_S0_Sub0_mip4_ref              0.000000   0.113362
# dhfr-ts_S0_Sub0_mip3               0.000398   0.158503
# ama1_S0_Sub0_mip2_ref              0.000188   0.154575
# dhps_S0_Sub0_mip5                  0.000000   0.197966
# ama1_S0_Sub0_mip0_ref              0.000477   0.192867
# dhps_S0_Sub0_mip6                  0.000000   0.195174
# k13_S0_Sub0_mip8_ref               0.000000   0.345526
# nhe_S0_Sub0_mip0                   0.000000   0.486598
# pib7_S0_Sub1_mip13_ref             0.000000   0.584059
# crt_S0_Sub2_mip6_ref               0.000195   0.622833
# crt_S0_Sub2_mip4_ref               0.000000   0.630312
# crt_S0_Sub2_mip5_ref               0.000000   0.671914
# crt_S0_Sub1_mip3_ref               0.000000   0.890147
# k13_S0_Sub0_mip0_ref               0.000000   0.812291
# crt_S0_Sub1_mip2_ref               0.000000   0.923626
# PF3D7-1322700_S0_Sub0_mip0_ref     0.000000   0.955020
# crt-dup_S0_Sub0_mip0_ref           0.000000   0.996378
# crt-dup_S0_Sub0_mip1_ref           0.000000   1.000000
